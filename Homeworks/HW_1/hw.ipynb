# %% [markdown]
# # ????? ????????? ????????
#
# <a href="https://mipt.ru/science/labs/laboratoriya-neyronnykh-sistem-i-glubokogo-obucheniya/"><img align="right" src="https://avatars1.githubusercontent.com/u/29918795?v=4&s=200" alt="DeepHackLab" style="position:relative;top:-40px;right:10px;height:100px;" /></a>
#
#
#
# ### ??????-????? ?????????? ?????????? ? ??????????? ????
# ### ??????????? ????????? ????? ? ????????? ???????? (DeepHackLab)

# %% [markdown]
# ## ???????? ??????? 1
# ### ?????? Python ? ????? NumPy
# ---

# %%
import numpy as np
import random
import scipy.stats as sps

# %% [markdown]
# ### ?????? 1
# ? ?????? ?????? ??? ???????????? ??????????? ??? ?????????? ??????? ????? ????????? -- ??? ????????????? ?????? ***numpy*** ? ? ???.

# %%
# ??? ????????? ?????? ?????????? ??????? random -- ??? ???????????? ??? ????????? ????????? ???????? 
# ??????? sample ??????? ????????? ???????. ? ???????? ????????? ?? ?????????? ?????? (i,j), ????? i -- ????? ?????,
# j -- ????? ????????.
a = np.random.sample((10,10))
b = np.random.sample((10,10))
# ???????? ??????????? (????) ?????? ??????? ? ??????? ??????? ndim.
# ??????????? ??????? shape, ??? ??? ???????
# ========
# ??? ????? ?????? ??? 
# ========
print(a)
print(b)

# %%
def mult(a, b):
    # ????? ???????? ???????????? ?????? ??? 
    # ????????????? NumPy ? ???????? ????????? 
    pass

# %%
def np_mult(a, b):
    # ????? ???????? ???????????? ?????? ?
    # ?????????????? NumPy ? ???????? ?????????
    pass

# %%
# %%time
# ??????? ????? ?????? ??????? ??? NumPy
mult(a,b)

# %%
# %%time
# ??????? ????? ?????? ??????? ? NumPy
np_mult(a,b)

# %% [markdown]
# ### ?????? 2
# ???????? ???????, ??????? ?? ?????? ?????????????????? $\{A_i\}_{i=1}^n$ ?????? ?????????????????? $S_n$, ??? $S_k = \frac{A_1 + ... + A_k}{k}$.
# ?????????? -- ? ??????? ?????????? **NumPy** ? ??? ???. ???????? ????????, ????????? ?????????.

# %%
# ???????, ???????? ?????? ? ??????? NumPy
def sec_av(A):
    # ??? ??? ?????
    pass

# %%
# ??????? ??? NumPy
def stupid_sec_av(A):
    S = [0 for i in range(len(A))]
    for i in range(len(A)):
        # ??? ??? ?????
    for i in range(len(A)):
        # ??? ??? ?????
    return S

# ??????? ????????? ?????????????????? ? ???????? ?? ?? ????? ????????. 
# ?????? ??????? ?????? ???????? ~ ? 50 ??? ???????
A = sps.uniform.rvs(size=10 ** 7) 

# %time S1 = sec_av(A)
# %time S2 = stupid_sec_av(A)
#???????? ????????????:
np.abs(S1 - S2).sum()

# %% [markdown]
# ### ?????? 3
#
# ????? ????? ????????? ?????? $X$. ???? ????????? ????? ??????, ??? ??? ???????? ? ????????? ????????? ????????? ???????? ?? ????? $a$ (???? ??? ?? ???????, ?? ?? 1). ??? ?????? ???????? ????????? ??????? ????? ???????? ? ??? ? ???????? ? ???????? ??????? ???????????? ??????? ???? ?????????. ?????? $X$ ??? ???? ?????? ???????? ??? ?????????. ? ????? ????????? ????? ?????? X ? ??????????????? X ? ??????? ? ???????? ???????.

# %%
# ???????, ???????? ?????? ? ??????? NumPy
def transformation(X, a=1):
    # ??? ??? ?????
    return Y

# %%
# ???????, ???????? ??????  ??? NumPy
def stupid_transformation(X):
    # ??? ??? ?????
    return Y

# %%
X = sps.uniform.rvs(size=10 ** 7) 
# ????? ??? ??????????? ???????? ? 20 ???. 
# ???? ?? ????? ?????????? ???????? ?????? ??? np -- ????? ??????? ?????????? ?? ??? ??????
# %time S1 = transformation(X)
# %time S2 = stupid_transformation(X)
# ???????? ????????????:
np.abs(S1 - S2).sum()

# %% [markdown]
# ?????? ?????? ***numpy*** ??????????? ????????????

# %%
# ??? ?????

# %% [markdown]
# ## ?????????????? ??????

# %% [markdown]
# ?????????????? ?????? ?????????????, ??? ?? ?????????????? ??????????? ? ????????? ???????? ***numpy***, ????? ?? ???????.
#
# ??? ?????? ?? ???????? ?????????????, ?? ????? ???????? ?? ??? ??????? ? ?????? ??????? (?????? ??????? ????? ???. ????? ????? ???????? ?????).

# %% [markdown]
# ### ?????? 4*

# %% [markdown]
# ???? ??????? ???? ??????????: $f(x, y) = sin(x)cos(y)$ (??? ?????? ????? ???????? 3D-??????), ? ????? ???? ??????? ??? ????????? $f(x, y)$ (`draw_f()`), ??????? ????????? ?? ???? ????????? ?????, ?? ??????? ????? ??????????? ???????.
#
# ??? ????? ??????????? ? ???, ??? ??????? ????? ????? (????????? - ??? ???? ?????????? ??????? ***numpy***), ? ?????? ????? ????? ?? ???? ??????? ?????????.

# %%
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

def f(x, y):
    '''??????? ???? ??????????'''
    return np.sin(x) * np.cos(y)

def draw_f(grid_x, grid_y):
    '''??????? ????????? ??????? f(x, y)'''
    fig = plt.figure(figsize=(10, 8))
    ax = Axes3D(fig)
    ax.plot_surface(grid_x, grid_y, f(grid_x, grid_y), cmap='inferno')
    plt.show()

# %%
grid_x, grid_y = # ??? ??? ?????

draw_f(gridx, gridy)

# %% [markdown]
# ### ?????? 5*

# %% [markdown]
# ??? ???? ????????. ??? ???????? ?? ??????????? ????? 3: **(w, h, num_channels)**, ??? **w** - ?????? ???????? ? ????????, **h** - ?????? ???????? ? ????????, **num_channels** - ?????????? ??????? *(R, G, B, alpha)*.
#
# ??? ????? "??????????" ???????? ? ?????????? ?????? ??????? w \* h \* num_channels, ??????? **???? ?????? ????**.

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
path_to_image = './image.png'
image_array = plt.imread(path_to_image)
plt.imshow(image_array);

# %%
flat_image_array = # ??? ??? ?????

# %%
# ????? ???????? ?????? ?????? ???????
